# %% [markdown]
# # B_rag_artigos_cientificos
#
# Pipeline inicial de RAG científico para o projeto DIVEA.

# %% [markdown]
# ## Objetivos
# - carregar PDFs científicos
# - gerar embeddings
# - criar banco vetorial
# - realizar busca semântica

# %%
from pathlib import Path
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader

# %%
PDF_DIR = "/data/projects/artigos"
CHUNK_SIZE = 1000
CHUNK_OVERLAP = 200

# %%
pdfs = list(Path(PDF_DIR).glob("*.pdf"))
pdfs[:5]

# %% [markdown]
# ## Estrutura esperada

# %% [markdown]
# ```text
# /data/projects/artigos/
# ├── bioestatistica/
# ├── epidemiologia/
# ├── rnds/
# └── interoperabilidade/
# ```

# %% [markdown]
# ## Próximos passos
# - instalar ChromaDB
# - integrar nomic-embed-text
# - conectar ao Open WebUI
